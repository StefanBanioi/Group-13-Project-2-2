# %%
import tensorflow as tf

model = tf.keras.models.load_model('model_ANN.keras')

print(model)
# Out:
# <Sequential name=sequential_15, built=True>

# %%
model.summary()
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_407 (Dense)               │ (None, 110)            │        16,170 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_392 (LeakyReLU)     │ (None, 110)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_408 (Dense)               │ (None, 110)            │        12,210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_393 (LeakyReLU)     │ (None, 110)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_409 (Dense)               │ (None, 110)            │        12,210 │
# ...

# %%
import pandas as pd
#import scaler.pkl from file
import joblib
#load the scaler
scaler = joblib.load('scaler.pkl')
data = pd.read_csv('one_hot_encoded.csv')
data = data.drop(columns=['claim'])
#save column names
column_names = data.columns
data = scaler.transform(data)
#only keep the first 1000 rows
data = data[0]
print(data)
data = data.reshape(1, -1)
print(model.predict(data))
# Out:
# [ 1.44749541 -0.04658002 -0.9635649  -0.08836562 -0.49223989  0.1826542
#  -1.91664185 -0.53422871 -1.02223043  1.02223043 -0.0948456  -0.07679066
#  -0.0799459  -0.10423146 -0.06737448 -0.09679275 -0.08223486 -0.06737448
#   0.26174611 -0.08519369 -0.14027193 -0.08663628 -0.11119351 -0.0664537
#  -0.09218776 -0.10482848 -0.13799164 -0.08875749 -0.10119581 -0.09807016
#  -0.08071591 -0.11615407 -0.14778197 -0.13799164 -0.09151166 -0.08805593
#  -0.08945373 -0.09218776 -0.0954989  -0.11882506 -0.08298418 -0.07916859
#  -0.08875749 -0.09743347 -0.09614792 -0.11342362 -0.12298462 -0.08591792
#  -0.13093073 -0.0948456  -0.13189248 -0.07916859 -0.0873489  -0.08663628
#  -0.0873489  -0.09151166 -0.11776354 -0.08945373 -0.0948456  -0.11561287
#  -0.09352579 -0.11231382 -0.13753139 -0.11287002 -0.08519369 -0.08519369
#  -0.08805593 -0.13799164 -0.11452321 -0.08147883 -0.08519369 -0.0908307
#  -0.11561287 -0.14648237 -0.13237091  9.70614766 -0.13753139 -0.1166929
# ...

# %%
#convert the numpy data to pandas dataframe
data = pd.DataFrame(data, columns=column_names)

# %%
# Out:
# None
# True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 18
#      15     print(f"Model is not fitted yet.")
#      17 print(model.initialized_)
# ---> 18 PartialDependenceDisplay.from_estimator(model, X=data, features=features, feature_names=column_names).plot(X=data)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\inspection\_plot\partial_dependence.py:703, in PartialDependenceDisplay.from_estimator(cls, estimator, X, features, sample_weight, categorical_features, feature_names, target, response_method, n_cols, grid_resolution, percentiles, method, n_jobs, verbose, line_kw, ice_lines_kw, pd_line_kw, contour_kw, ax, kind, centered, subsample, random_state)
#     697         raise ValueError(
#     698             f"When a floating-point, subsample={subsample} should be in "
#     699             "the (0, 1) range."
#     700         )
# ...
